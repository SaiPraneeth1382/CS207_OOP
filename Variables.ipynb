# %%
sum = 10    ##Global Variables
var1 = 20
var2 = 30

# %%
print(type(var1))

# %%
print(id((var1)))   ##Object Identifies

# %%
print(sum + var1 + var2)
def inner_func():
    a = 30          ##Local variables
    print("a : ", a)
inner_func()
##print(a)
##we cannot access local variables outside a function

# %% [markdown]
# Multiple variable Assignment
# <br>
# a = b = c = 40<br>
# d = e = 50<br>
# print(a + d)<br>
# Name = name = "Soumya Ranjan Sahu"<br>
# print(Name, name)<br>
# ##Max possible value of Integers in python<br>
# c = 9999999999999999999999999999999999<br>
# print(c + 1)<br>
# print(type(c))
