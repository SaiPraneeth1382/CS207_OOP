# %%
a = 0b0010  #Binary Literals
b = 100     #Decimal Literals
c = 0o310   #Octal Literals
d = 0x02b    #Hexadecimal Literals

# %% [markdown]
# loat Literals

# %%
x = 0.2354554

# %% [markdown]
# omplex Literals

# %%
y = 5.23j

# %%
print(a, b, c, d, x, y)

# %% [markdown]
# tring Literals

# %%
z = "Kanha"

# %%
print(z)

# %% [markdown]
# oolean Literals

# %%
m = (1 == True)
n = (1 == False)
l = True + 5
o = False + 20
k = False
print("m is ", m)
print("n is ", n)
print("l:", l)
print("o:", o)
print("k is ", k)

# %% [markdown]
# pecial Literals

# %%
junk = None
food = "Available"
print(junk, food)
def Food(food):
    if food == "food":
        print("AVailable")
    else:
        print("Not Available")
Food(junk)
Food(food)

# %% [markdown]
# iteral Collections

# %% [markdown]
# ist

# %%
list = ["My", "Name", "is", "Kanha"]
print(list)

# %% [markdown]
# uple

# %%
Numbers = (0, 5, 75, 10)
letters = ('a', 'b', 'c', 'd')
print(Numbers)
print(letters)

# %% [markdown]
# ictionary

# %%
data = {"a" : "apple", "b" : "ball", "c" : "Cat"}
print(data)

# %% [markdown]
# et

# %%
vowels = {"a", "e", "i", "o", "u"}
print(vowels)
